# %%
# %load_ext dotenv
# %dotenv
# Out:
# The dotenv extension is already loaded. To reload it, use:
#   %reload_ext dotenv

# %%
import os
import openai
import dotenv

openai.api_key = os.getenv("OPEN_API_KEY")

response = openai.ChatCompletion.create(
  model="gpt-3.5-turbo",
  messages=[
    {"role": "system", "content": "You are a poetic assistant, skilled in explaining complex programming concepts with creative flair."},
    {"role": "user", "content": "Compose a poem that explains the concept of recursion in programming."}
  ]
)

print(response['choices'][0]['message']['content'])
# Out:
# In the realm where algorithms unfold,
# Where logic's tales are deftly told,
# There blooms a concept, both profound and clear,
# A dance of repetition, called recursion, my dear.
#
# Imagine a function, a magical spell,
# With power unmatched, it casts so well,
# It boasts a trait, unique and rare,
# To call itself and venture there.
#
# Like a mirror reflecting in infinite measure,
# A fractal dance of coding treasure,
# Recursion breathes a life divine,
# As it journeys within its own design.
#
# Picture a maze, a labyrinth grand,
# With pathways crooked, and loops that expand,
# To solve this enigma, elegant and fair,
# Recursion arrives, like a whispered prayer.
#
# It takes a step, then another you see,
# Unraveling the puzzle, layer by layer, with glee,
# Each recursive call, a guide in disguise,
# Sifting through complexity, as shadows untie.
#
# With each passing iteration, it dives deeper still,
# Peering into the abyss, with an unyielding will,
# ...

# %%
import os
import openai

openai.api_key = os.getenv("OPEN_API_KEY")

# %%
def get_completion(prompt, model="gpt-3.5-turbo"):
    messages = [{"role": "user", "content": prompt}]
    response = openai.ChatCompletion.create(
        model=model,
        messages=messages,
        temperature=0, # this is the degree of randomness of the model's output
    )
    return response.choices[0].message["content"]

def get_completion_from_messages(messages, model="gpt-3.5-turbo", temperature=0):
    response = openai.ChatCompletion.create(
        model=model,
        messages=messages,
        temperature=temperature, # this is the degree of randomness of the model's output
    )
#     print(str(response.choices[0].message))
    return response.choices[0].message["content"]

# %%
messages =  [  
{'role':'system', 'content':'You are friendly chatbot.'},    
{'role':'user', 'content':'Hi, my name is Clara'}  ]
response = get_completion_from_messages(messages, temperature=1)
print(response)

# %%
def collect_messages(_):
    prompt = inp.value_input
    inp.value = ''
    context.append({'role':'user', 'content':f"{prompt}"})
    response = get_completion_from_messages(context) 
    context.append({'role':'assistant', 'content':f"{response}"})
    panels.append(
        pn.Row('User:', pn.pane.Markdown(prompt, width=600)))
    panels.append(
        pn.Row('Assistant:', pn.pane.Markdown(response, width=600, styles={'background-color': '#F6F6F6'})))
 
    return pn.Column(*panels)

# %%
import panel as pn  # GUI
pn.extension()

panels = [] # collect display 

topic_7 = """This topic is about Exceptions and Exception Handling. 
An exception is an error detected during the execution of the code. 
Exception handling is instead the process that deals with the execution error, avoiding the programme to crash.
Example 1:
“””
print("Please, enter a number:") 
x=int(input()) 
x=x+6 
print(x)
“””
In this piece of code above we ask the user to enter a number, however what happens if the user enters a word or simply anything that isn’t a number? 
The terminal will print a ValueError message, because the code expects to receive a integer, and the user inputted a sequence of letters.
ValueError is just one type of exception, which indicates inappropriate value is received. 
There are other types of exceptions like:
-NameError: name of inexistent variable. 
-ZeroDivisionError: the second argument of a division or modulo operation is zero.
For more information about exceptions the student cann visit this page: https://docs.python.org/3/library/exceptions.html
Now, we introduce the students to Exception handling by showing this piece of code: 
try:
    print("Please, enter a number:")
    x=int(input())
    x=x+6
    print(x)
except:
    print(“You have not entered a number”)
Above, you can see the previous code with two additional instructions: try and except.
Inside the try instruction we have written our previous code. In this way, the system is going to
execute these instructions under try mode. If everything goes fine, that is, if there is no error when
executing the instructions inside the try statement, the statement except is ignored. 
Instead, if the try block rises an error, the instructions in the except block will be executed.

By using the try/except the programme stops from crashing when the user enters a wrong input. Instead of crashing,
a message indicating the problem is printed on screen and the programme ends
normally. Now that you know the basics of handling errors, please use them as much as possible to
prevent your programmes from crashing due to execution errors. 

There are cases where you want your programme to raise an exception specific to the problem you are solving. For example, 
you want the user to enter a number in a given range. If the user enters a number out of range, 
you would like to raise an exception.

In that case, we use the instruction raise, followed by the type of error that has occurred.
Let’s see an example.

try:
    print("Please, enter a number between 1 and 10:")
    x=int(input())
    if (x<1 or x>10):
		raise IndexError
    x=x+6
    print(x)
except ValueError:
    print("You have not entered a number")
        except IndexError:
print("Number out of range")

This code is the same code we just visited that has been extended to ask for the user to enter a number in a range. 
We instruct the user to enter a number in a range: between 1 and 10. 
We check whether the user has complied with entering a number between 1 and 10. If not, we raise an exception of type IndexError. 
You can choose any built-in type here, but it is good to select one close to the error occurring. 
Since this is an out of range error, and there is no error in that category, 
I have chosen this that refers to the case when an array index is out of range. 
Finally, we have now two excepts, one for each type of error. 
In that case, a different message will be displayed on the screen depending on what error has occurred.

"""

context = [ {'role':'system', 'content':"""

The students of ELEC0021 are studying the Python programming language starting at beginner level. They have learned C programming language in first year, therefore they already know at least one programming language. 
Your role is to help the students learn Python from scratch, guiding them to transfer their knowledge from C to Python. As a chatbot which is currently under development, you will teach the students only on the first week of term, which is about the basics of Python. Here are the topics taught in week 1:
```{topic_7  }```
Given the topics above, you are a tutor helping students learn Python. You will need to welcome the students with a the following message:

"The aim of PyBot is to tutor students enrolled on the ELEC0021 module on the Python programming langauge - specifically, 
the Week 1 Topic (Introduction to Procedural Python). 
PyBot is powered by the OpenAI API gpt-3.5-turbo model and it has been trained on teaching resources.
Disclaimer: 'PyBot is GDPR compliant. All users will remain anonymous and all inputs provided to PyBot will not be used for further training. 
Please refer to Dr. Alejandra Beghelli for further information. Terms of Service (ToS): PyBot should only be used for summative assessments 
in accordance with UCL policy (https://www.ucl.ac.uk/students/exams-and-assessments/assessment-success-guide/engaging-ai-your-education-and-assessment). 
PyBot does not condone, incite and/or generates inappropriate content that violates OpenAIs usage polices. 
By using this application, you acknowledge the Disclaimer and agree to abide by the ToS."
After this, you will ask the student what level of Python knowledge they have between beginner, intermediate, advanced.  
Once they have replied, you can start giving them exercises bases on their knowledge.
Act as a tutor to provide the students with guidance and feedback on their answers to the exercises. 
In any case, DO NOT provide the solution to the exercise to the students. 

"""} ]  # accumulate messages


inp = pn.widgets.TextInput(value="Hi", placeholder='Enter text here…')
button_conversation = pn.widgets.Button(name="Chat!")

interactive_conversation = pn.bind(collect_messages, button_conversation)

dashboard = pn.Column(
    inp,
    pn.Row(button_conversation),
    pn.panel(interactive_conversation, loading_indicator=True, height=300),
)
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='1b4ff460-159e-4bc6-98d0-4dd2e7ec4dad'>
#   <div id="dd2e634c-5923-4af6-861a-165fd6af9aec" data-root-id="1b4ff460-159e-4bc6-98d0-4dd2e7ec4dad" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...

# %%
dashboard
# Out:
# <pre>Traceback (most recent call last):
#   File &quot;c:\Users\clara\anaconda3\envs\OpenAI\Lib\site-packages\pyviz_comms\__init__.py&quot;, line 340, in _handle_msg
#     self._on_msg(msg)
#   File &quot;c:\Users\clara\anaconda3\envs\OpenAI\Lib\site-packages\panel\viewable.py&quot;, line 467, in _on_msg
#     patch.apply_to_document(doc, comm.id if comm else None)
#   File &quot;c:\Users\clara\anaconda3\envs\OpenAI\Lib\site-packages\bokeh\protocol\messages\patch_doc.py&quot;, line 104, in apply_to_document
#     invoke_with_curdoc(doc, lambda: doc.apply_json_patch(self.payload, setter=setter))
#   File &quot;c:\Users\clara\anaconda3\envs\OpenAI\Lib\site-packages\bokeh\document\callbacks.py&quot;, line 443, in invoke_with_curdoc
#     return f()
#            ^^^
#   File &quot;c:\Users\clara\anaconda3\envs\OpenAI\Lib\site-packages\bokeh\protocol\messages\patch_doc.py&quot;, line 104, in &lt;lambda&gt;
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 intermidiate
#
# NameError: name 'intermidiate' is not defined
